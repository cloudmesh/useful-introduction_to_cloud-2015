# %% [markdown]
# # bla bal

# %% [markdown]
# # from sh import ls

# %% [markdown]
# hello world

# %%
ls("-1")
# Out:
# 000_hello_cloudmesh.ipynb
# 001_vm-sh.ipynb
# 003-cloudmesh-shell.ipynb
# Hello_cloudmesh.rst
# Untitled0.ipynb
# cm.py

# %%
import cloudmesh

# %%
print cloudmesh.load()
# Out:
# {
#     "cloudmesh": {
#         "profile": {
#             "username": "TBD",
#             "uid": null,
#             "firstname": "TBD",
#             "lastname": "TBD",
#             "phone": "TBD",
#             "gid": null,
#             "address": [
#                 "TBD"
#             ],
#             "email": null
#         },
#         "hpc": {
#             "username": "TBD"
#         },
#         "clouds": {
#             "alamo": {
#                 "cm_label": "alamo",
#                 "cm_host": "alamo.futuregrid.org",
#                 "default": {
#                     "flavor": "None",
#                     "image": "None"
#                 },
#                 "credentials": {
#                     "NOVA_CERT": "/Users/flat/.cloudmesh/alamo/cacert.pem",
#                     "EC2_URL": "https://openstack.futuregrid.tacc.utexas.edu:8773/services/Cloud",
#                     "userid": "TBD",
# ...

# %%
print cloudmesh.load().firstname
# Out:
# TBD
